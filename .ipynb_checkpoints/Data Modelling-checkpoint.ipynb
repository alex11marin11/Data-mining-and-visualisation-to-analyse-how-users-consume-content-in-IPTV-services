# %%
import pandas as pd
from pandas_profiling import ProfileReport
from sklearn.preprocessing import LabelEncoder, Normalizer
import seaborn as sns
import matplotlib.pyplot as plt
from apyori import apriori

# %%
data = pd.read_csv('Data/Extraction 3/Clean data 3.csv')
data.head()
# Out:
#                                              user_id channel_name  program_id  \
# 0  f1b9ff065d526bb021216d90a92455a2f036f26c74ac95...          CHV   267517334
# 1  f1b9ff065d526bb021216d90a92455a2f036f26c74ac95...         MEGA   267606959
# 2  f1b9ff065d526bb021216d90a92455a2f036f26c74ac95...         MEGA   264213105
# 3  68db52682dcf2f0dff42f36ce26abe2003d87ca76142b4...          TVN   267607757
# 4  aabc1623e0307bbaf08c0e85fb507ba08f5f18fe8ad5fe...          CHV   267517392
#
#                        program_name  program_theme         program_subtheme  \
# 0                  LA DIVINA COMIDA  MSEPG_SPECIAL         Reality,Culinary
# 1                ESPECIAL DE PRENSA  MSEPG_SPECIAL                Interview
# 2            MEGANOTICIAS ACTUALIZA     MSEPG_NEWS  Interview,Politics,News
# 3                       CHILE ELIGE     MSEPG_NEWS       Interview,Politics
# 4  EL DISCÍPULO DEL CHEF - LO MEJOR  MSEPG_SPECIAL         Reality,Culinary
#
#        date_time_start        end_date_time        program_start  \
# 0  2021-12-18 22:31:22  2021-12-18 22:47:26  2021-12-18 22:30:00
# 1  2021-12-19 19:57:34  2021-12-19 20:21:31  2021-12-19 15:30:00
# 2  2021-12-19 13:01:22  2021-12-19 13:57:00  2021-12-19 13:00:00
# 3  2021-12-19 20:18:51  2021-12-19 20:20:51  2021-12-19 15:00:00
# 4  2021-12-19 01:48:00  2021-12-19 02:04:00  2021-12-19 01:15:00
#
#            program_end device_type_used service_name  service_source  \
# 0  2021-12-19 01:15:00               TV           Go               2
# 1  2021-12-19 20:30:00               TV           Go               2
# 2  2021-12-19 15:30:00               TV           Go               2
# 3  2021-12-19 21:00:00               TV           Go               2
# 4  2021-12-19 02:20:00               TV           Go               2
#
#    service_subtype  service_type  duration  type service
# 0              102          1003       964  live     ITV
# 1              102          1003      1437  live     ITV
# 2              102          1003      3338  live     ITV
# 3              102          1003       120  live     ITV
# 4              102          1003       960  live     ITV

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203065 entries, 0 to 203064
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_id           203065 non-null  object
#  1   channel_name      200546 non-null  object
#  2   program_id        203065 non-null  int64
#  3   program_name      203065 non-null  object
#  4   program_theme     203065 non-null  object
#  5   program_subtheme  202711 non-null  object
#  6   date_time_start   203065 non-null  object
#  7   end_date_time     203065 non-null  object
#  8   program_start     200546 non-null  object
#  9   program_end       200546 non-null  object
#  10  device_type_used  203065 non-null  object
#  11  service_name      203065 non-null  object
#  12  service_source    203065 non-null  int64
#  13  service_subtype   203065 non-null  int64
#  14  service_type      203065 non-null  int64
#  15  duration          203065 non-null  int64
#  16  type              203065 non-null  object
#  17  service           203065 non-null  object
# dtypes: int64(5), object(13)
# memory usage: 27.9+ MB

# %%
# for i in range(len(data.columns)):
#     print(data.iloc[:,i].value_counts())

# %%
# import seaborn as sb
# corr = data.corr()
# sb.heatmap(corr, cmap="Blues", annot=True)

# %% [markdown]
# Drop:
#     - program_id
#     - service_name
#     - service_source
#     - service_subtype
#     - service_type

# %%
# Drop not useful columns
df = data.drop(['program_id', 'service_name', 'service_subtype', 'service_type'], axis=1)

# Change names
df.loc[df['program_theme'].isin(['MSEPG_SPECIAL']), 'program_theme'] = 'Special'
df.loc[df['program_theme'].isin(['MSEPG_NEWS']), 'program_theme'] = 'News'
df.loc[df['program_theme'].isin(['MSEPG_MOVIE']), 'program_theme'] = 'Movie'
df.loc[df['program_theme'].isin(['MSEPG_SPORTS']), 'program_theme'] = 'Sports'
df.loc[df['program_theme'].isin(['MSEPG_SERIES']), 'program_theme'] = 'Series'
df.loc[df['program_theme'].isin(['MSEPG_KIDS']), 'program_theme'] = 'Kids'
df.loc[df['program_theme'].isin(['MSEPG_PaidProgramming']), 'program_theme'] = 'Paid'
df.loc[df['program_theme'].isin(['MSEPG_SHORTFILM']), 'program_theme'] = 'Shortfilm'
df.loc[df['program_theme'].isin(['Movie']), 'program_theme'] = 'Movie'
df.loc[df['program_theme'].isin(['Episode']), 'program_theme'] = 'Series'

# Fill NA values
df.fillna(value={'channel_name':'VOD'}, inplace=True)
df['program_start'].fillna(df['date_time_start'], inplace=True)
df['program_end'].fillna(df['end_date_time'], inplace=True)
df['program_subtheme'].fillna(df['program_theme'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203065 entries, 0 to 203064
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_id           203065 non-null  object
#  1   channel_name      203065 non-null  object
#  2   program_name      203065 non-null  object
#  3   program_theme     203065 non-null  object
#  4   program_subtheme  203065 non-null  object
#  5   date_time_start   203065 non-null  object
#  6   end_date_time     203065 non-null  object
#  7   program_start     203065 non-null  object
#  8   program_end       203065 non-null  object
#  9   device_type_used  203065 non-null  object
#  10  service_source    203065 non-null  int64
#  11  duration          203065 non-null  int64
#  12  type              203065 non-null  object
#  13  service           203065 non-null  object
# dtypes: int64(2), object(12)
# memory usage: 21.7+ MB

# %%
# profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)
# profile

# %%
# df['norm_duration'] = (df['duration'] - df['duration'].mean()) / df['duration'].std()
# df['norm_duration'].describe()
# hist = df['norm_duration'].value_counts().hist()

# %%
# le = LabelEncoder()
# for i in ['device_type_used', 'service_source', 'type', 'service']:
#     df[i] = le.fit_transform(df[i])
# df_tot = df
# df_tot.head(5)

# %% [markdown]
# ### Apriori Algorithm

# %%
def print_apyori_output (association_results):
    for relation_record in association_results:
        itemset = list(relation_record.items)
        
        # Consider only itemsets of two elements
        if len(itemset) > 1: 
        
            print("Rules involving itemset %s" % itemset)
            support = relation_record.support

            for rules in relation_record.ordered_statistics:
                antecedent = list(rules.items_base)
                consequent = list(rules.items_add)
                confidence = rules.confidence
                lift = rules.lift

                print("%s => %s (support=%.2f, confidence=%.2f, lift=%.2f)" %
                      (antecedent, consequent, support, confidence, lift))
            print()

# %%
# # If we want to distinguish between 1st, 2nd, ... position use this
# df_subthemes = df['program_subtheme'].str.split(',', expand=True)
# df_subthemes = pd.get_dummies(data=df['program_subtheme'].str.split(',', expand=True)) # dummy_na = True ???

# # If we do not care about position use this
# df_subthemes = df['program_subtheme'].str.split(',', expand=True)
# df_subthemes = pd.get_dummies(data=df['program_subtheme'].str.split(',', expand=True), prefix='', prefix_sep='')
# df_subthemes = df_subthemes.groupby(df_subthemes.columns, axis=1).sum()

# # Then we run this to get all of them
# transactions = []
# for recordnum, record in subthemes_list.iterrows():
#     transact = []
#     for column in subthemes_list.columns:      # For each column
#         if record[column] != 0:              # If it has the subtheme
#             transact.append(column)          # We append the subtheme to that transaction
#     transactions.append(transact)            # We append the transaction to the list of transactions
    
# transactions

# %%
# This line is equivalent to all of the above
transactions = df['program_subtheme'].str.split(',').to_list()

# %%
# df_subthemes = df['program_subtheme'].str.split(',', expand=True)
# df_subthemes = pd.get_dummies(data=df['program_subtheme'].str.split(',', expand=True), prefix='', prefix_sep='')
# df_subthemes = df_subthemes.groupby(df_subthemes.columns, axis=1).sum()

# %%
# corr = df_subthemes.corr()
# sns.heatmap(corr, cmap="Blues", annot=False)
# plt.savefig('corr.png')

# %% [markdown]
# #### Example
# Support(News) = (Transactions containing (News)) / (Total Transactions)
#
# Support(Interview) = (Transactions containing (Interview)) / (Total Transactions)
#
# Confidence(News→Interview) = (Transactions containing both (News and Interview)) / (Transactions containing News) = 8/10 = 0.80
#
# Lift(News→Interview) = (Confidence (News→Interview)) / (Support (Interview)) = 0.8/0.75 = 1.07

# %% [markdown]
# #### High-support rules

# %%
results = apriori(transactions, min_support=0.1, min_confidence=0.49, min_lift=1)
print_apyori_output(results)
# Out:
# Rules involving itemset ['News', 'Interview']
# ['Interview'] => ['News'] (support=0.12, confidence=0.57, lift=3.12)
# ['News'] => ['Interview'] (support=0.12, confidence=0.67, lift=3.12)
#
# Rules involving itemset ['Politics', 'Interview']
# ['Interview'] => ['Politics'] (support=0.11, confidence=0.50, lift=3.54)
# ['Politics'] => ['Interview'] (support=0.11, confidence=0.76, lift=3.54)
#
# Rules involving itemset ['News', 'Politics']
# ['News'] => ['Politics'] (support=0.12, confidence=0.65, lift=4.68)
# ['Politics'] => ['News'] (support=0.12, confidence=0.85, lift=4.68)

# %% [markdown]
# #### High-lift rules

# %%
results = apriori(transactions, min_support=0.023, min_confidence=0.5, min_lift=8)
print_apyori_output(results)
# Out:
# Rules involving itemset ['Adventure', 'Animation']
# ['Adventure'] => ['Animation'] (support=0.03, confidence=0.58, lift=9.84)
# ['Animation'] => ['Adventure'] (support=0.03, confidence=0.50, lift=9.84)
#
# Rules involving itemset ['Children', 'Animation']
# ['Children'] => ['Animation'] (support=0.02, confidence=0.74, lift=12.44)
#
# Rules involving itemset ['Business', 'Politics', 'Interview']
# ['Business'] => ['Politics', 'Interview'] (support=0.02, confidence=0.87, lift=8.23)

# %%
results = apriori(transactions, min_support=0.025, min_confidence=0.5, min_lift=5)
print_apyori_output(results)
# Out:
# Rules involving itemset ['Adventure', 'Animation']
# ['Adventure'] => ['Animation'] (support=0.03, confidence=0.58, lift=9.84)
# ['Animation'] => ['Adventure'] (support=0.03, confidence=0.50, lift=9.84)
#
# Rules involving itemset ['Drama', 'Soap']
# ['Soap'] => ['Drama'] (support=0.04, confidence=0.91, lift=5.66)
#
# Rules involving itemset ['News', 'Current Events', 'Politics']
# ['Politics', 'Current Events'] => ['News'] (support=0.03, confidence=0.98, lift=5.39)
#
# Rules involving itemset ['News', 'Interview', 'Politics']
# ['Politics'] => ['News', 'Interview'] (support=0.09, confidence=0.67, lift=5.53)
# ['News', 'Interview'] => ['Politics'] (support=0.09, confidence=0.77, lift=5.53)

# %% [markdown]
# #### High-support & High-lift rules

# %%
results = apriori(transactions, min_support=0.03, min_confidence=0.2, min_lift=5)
print_apyori_output(results)
# Out:
# Rules involving itemset ['Drama', 'Soap']
# ['Drama'] => ['Soap'] (support=0.04, confidence=0.23, lift=5.66)
# ['Soap'] => ['Drama'] (support=0.04, confidence=0.91, lift=5.66)
#
# Rules involving itemset ['News', 'Interview', 'Politics']
# ['Politics'] => ['News', 'Interview'] (support=0.09, confidence=0.67, lift=5.53)
# ['News', 'Interview'] => ['Politics'] (support=0.09, confidence=0.77, lift=5.53)

# %% [markdown]
# ## Subtheme + Hour Transaction

# %%
df_hour = df['date_time_start'].astype('datetime64').dt.hour.astype(str)
df_subtheme = df['program_subtheme']

hour_subtheme_df = df_hour + ',' + df['program_subtheme']
hour_subtheme_transactions = hour_subtheme_df.str.split(',').to_list()

results = apriori(hour_subtheme_transactions, min_support=0.03, min_confidence=0.2, min_lift=5)
print_apyori_output(results)
# Out:
# Rules involving itemset ['Drama', 'Soap']
# ['Drama'] => ['Soap'] (support=0.04, confidence=0.23, lift=5.66)
# ['Soap'] => ['Drama'] (support=0.04, confidence=0.91, lift=5.66)
#
# Rules involving itemset ['News', '21', 'Interview']
# ['21', 'Interview'] => ['News'] (support=0.03, confidence=0.93, lift=5.12)
#
# Rules involving itemset ['21', 'Interview', 'Politics']
# ['Politics'] => ['21', 'Interview'] (support=0.03, confidence=0.22, lift=6.63)
# ['21', 'Interview'] => ['Politics'] (support=0.03, confidence=0.93, lift=6.63)
#
# Rules involving itemset ['News', '21', 'Politics']
# ['News'] => ['21', 'Politics'] (support=0.04, confidence=0.22, lift=5.42)
# ['Politics'] => ['21', 'News'] (support=0.04, confidence=0.29, lift=7.03)
# ['News', '21'] => ['Politics'] (support=0.04, confidence=0.98, lift=7.03)
# ['21', 'Politics'] => ['News'] (support=0.04, confidence=0.98, lift=5.42)
#
# Rules involving itemset ['News', 'Interview', 'Politics']
# ['Politics'] => ['News', 'Interview'] (support=0.09, confidence=0.67, lift=5.53)
# ['News', 'Interview'] => ['Politics'] (support=0.09, confidence=0.77, lift=5.53)
#
# Rules involving itemset ['News', '21', 'Interview', 'Politics']
# ['Politics'] => ['21', 'News', 'Interview'] (support=0.03, confidence=0.22, lift=7.11)
# ['21', 'Interview'] => ['News', 'Politics'] (support=0.03, confidence=0.92, lift=7.78)
# ['News', '21'] => ['Politics', 'Interview'] (support=0.03, confidence=0.77, lift=7.28)
# ['21', 'Politics'] => ['News', 'Interview'] (support=0.03, confidence=0.77, lift=6.37)
# ['News', 'Interview'] => ['21', 'Politics'] (support=0.03, confidence=0.26, lift=6.37)
# ['Politics', 'Interview'] => ['21', 'News'] (support=0.03, confidence=0.30, lift=7.28)
# ['News', 'Politics'] => ['21', 'Interview'] (support=0.03, confidence=0.26, lift=7.78)
# ['News', '21', 'Interview'] => ['Politics'] (support=0.03, confidence=1.00, lift=7.11)
# ['21', 'Interview', 'Politics'] => ['News'] (support=0.03, confidence=1.00, lift=5.49)

# %% [markdown]
# ## Subtheme + Day of Week Transaction

# %%
df_day = df['date_time_start'].astype('datetime64').dt.day_name()
day_subtheme_df = df_day + ',' + df['program_subtheme']
day_subtheme_transactions = day_subtheme_df.str.split(',').to_list()

results = apriori(day_subtheme_transactions, min_support=0.03, min_confidence=0.2, min_lift=1)
print_apyori_output(results)
# Out:
# Rules involving itemset ['Drama', 'Comedy']
# ['Comedy'] => ['Drama'] (support=0.04, confidence=0.44, lift=2.73)
# ['Drama'] => ['Comedy'] (support=0.04, confidence=0.24, lift=2.73)
#
# Rules involving itemset ['News', 'Current Events']
# ['Current Events'] => ['News'] (support=0.05, confidence=0.85, lift=4.68)
# ['News'] => ['Current Events'] (support=0.05, confidence=0.26, lift=4.68)
#
# Rules involving itemset ['Drama', 'Soap']
# ['Drama'] => ['Soap'] (support=0.04, confidence=0.23, lift=5.66)
# ['Soap'] => ['Drama'] (support=0.04, confidence=0.91, lift=5.66)
#
# Rules involving itemset ['Drama', 'Tuesday']
# ['Tuesday'] => ['Drama'] (support=0.03, confidence=0.20, lift=1.26)
#
# Rules involving itemset ['Friday', 'Interview']
# ['Friday'] => ['Interview'] (support=0.03, confidence=0.24, lift=1.11)
#
# Rules involving itemset ['Interview', 'Monday']
# ['Monday'] => ['Interview'] (support=0.03, confidence=0.22, lift=1.01)
#
# Rules involving itemset ['News', 'Interview']
# ['Interview'] => ['News'] (support=0.12, confidence=0.57, lift=3.12)
# ['News'] => ['Interview'] (support=0.12, confidence=0.67, lift=3.12)
#
# Rules involving itemset ['Politics', 'Interview']
# ['Interview'] => ['Politics'] (support=0.11, confidence=0.50, lift=3.54)
# ['Politics'] => ['Interview'] (support=0.11, confidence=0.76, lift=3.54)
#
# Rules involving itemset ['Interview', 'Reportage']
# ['Interview'] => ['Reportage'] (support=0.06, confidence=0.27, lift=3.58)
# ['Reportage'] => ['Interview'] (support=0.06, confidence=0.77, lift=3.58)
#
# Rules involving itemset ['Thursday', 'Interview']
# ['Thursday'] => ['Interview'] (support=0.04, confidence=0.23, lift=1.08)
#
# Rules involving itemset ['Tuesday', 'Interview']
# ['Tuesday'] => ['Interview'] (support=0.03, confidence=0.22, lift=1.04)
#
# Rules involving itemset ['Wednesday', 'Interview']
# ['Wednesday'] => ['Interview'] (support=0.03, confidence=0.22, lift=1.04)
#
# Rules involving itemset ['News', 'Politics']
# ['News'] => ['Politics'] (support=0.12, confidence=0.65, lift=4.68)
# ['Politics'] => ['News'] (support=0.12, confidence=0.85, lift=4.68)
#
# Rules involving itemset ['News', 'Reportage']
# ['News'] => ['Reportage'] (support=0.05, confidence=0.28, lift=3.66)
# ['Reportage'] => ['News'] (support=0.05, confidence=0.66, lift=3.66)
#
# Rules involving itemset ['Sunday', 'News']
# ['Sunday'] => ['News'] (support=0.03, confidence=0.20, lift=1.10)
#
# Rules involving itemset ['Sunday', 'Politics']
# ['Politics'] => ['Sunday'] (support=0.03, confidence=0.22, lift=1.49)
# ['Sunday'] => ['Politics'] (support=0.03, confidence=0.21, lift=1.49)
#
# Rules involving itemset ['News', 'Interview', 'Politics']
# ['Interview'] => ['News', 'Politics'] (support=0.09, confidence=0.44, lift=3.69)
# ['News'] => ['Politics', 'Interview'] (support=0.09, confidence=0.52, lift=4.87)
# ['Politics'] => ['News', 'Interview'] (support=0.09, confidence=0.67, lift=5.53)
# ['News', 'Interview'] => ['Politics'] (support=0.09, confidence=0.77, lift=5.53)
# ['Politics', 'Interview'] => ['News'] (support=0.09, confidence=0.88, lift=4.87)
# ['News', 'Politics'] => ['Interview'] (support=0.09, confidence=0.79, lift=3.69)
#
# Rules involving itemset ['News', 'Interview', 'Reportage']
# ['Reportage'] => ['News', 'Interview'] (support=0.03, confidence=0.44, lift=3.66)
# ['News', 'Interview'] => ['Reportage'] (support=0.03, confidence=0.28, lift=3.66)
# ['Interview', 'Reportage'] => ['News'] (support=0.03, confidence=0.58, lift=3.20)
# ['News', 'Reportage'] => ['Interview'] (support=0.03, confidence=0.67, lift=3.12)

# %% [markdown]
# ## Subtheme + Day of Week Transaction

# %%
day_hour_subtheme_df = df_day + ',' + df_hour + ',' + df['program_subtheme']
day_hour_subtheme_transactions = day_hour_subtheme_df.str.split(',').to_list()

results = apriori(day_hour_subtheme_transactions, min_support=0.03, min_confidence=0.2, min_lift=5)
print_apyori_output(results)
# Out:
# Rules involving itemset ['Drama', 'Soap']
# ['Drama'] => ['Soap'] (support=0.04, confidence=0.23, lift=5.66)
# ['Soap'] => ['Drama'] (support=0.04, confidence=0.91, lift=5.66)
#
# Rules involving itemset ['News', '21', 'Interview']
# ['21', 'Interview'] => ['News'] (support=0.03, confidence=0.93, lift=5.12)
#
# Rules involving itemset ['21', 'Interview', 'Politics']
# ['Politics'] => ['21', 'Interview'] (support=0.03, confidence=0.22, lift=6.63)
# ['21', 'Interview'] => ['Politics'] (support=0.03, confidence=0.93, lift=6.63)
#
# Rules involving itemset ['News', '21', 'Politics']
# ['News'] => ['21', 'Politics'] (support=0.04, confidence=0.22, lift=5.42)
# ['Politics'] => ['21', 'News'] (support=0.04, confidence=0.29, lift=7.03)
# ['News', '21'] => ['Politics'] (support=0.04, confidence=0.98, lift=7.03)
# ['21', 'Politics'] => ['News'] (support=0.04, confidence=0.98, lift=5.42)
#
# Rules involving itemset ['News', 'Interview', 'Politics']
# ['Politics'] => ['News', 'Interview'] (support=0.09, confidence=0.67, lift=5.53)
# ['News', 'Interview'] => ['Politics'] (support=0.09, confidence=0.77, lift=5.53)
#
# Rules involving itemset ['News', '21', 'Interview', 'Politics']
# ['Politics'] => ['21', 'News', 'Interview'] (support=0.03, confidence=0.22, lift=7.11)
# ['21', 'Interview'] => ['News', 'Politics'] (support=0.03, confidence=0.92, lift=7.78)
# ['News', '21'] => ['Politics', 'Interview'] (support=0.03, confidence=0.77, lift=7.28)
# ['21', 'Politics'] => ['News', 'Interview'] (support=0.03, confidence=0.77, lift=6.37)
# ['News', 'Interview'] => ['21', 'Politics'] (support=0.03, confidence=0.26, lift=6.37)
# ['Politics', 'Interview'] => ['21', 'News'] (support=0.03, confidence=0.30, lift=7.28)
# ['News', 'Politics'] => ['21', 'Interview'] (support=0.03, confidence=0.26, lift=7.78)
# ['News', '21', 'Interview'] => ['Politics'] (support=0.03, confidence=1.00, lift=7.11)
# ['21', 'Interview', 'Politics'] => ['News'] (support=0.03, confidence=1.00, lift=5.49)

# %% [markdown]
# ## Subtheme + Device Transaction

# %%
device_subtheme_df = df['device_type_used'] + ',' + df['program_subtheme']
device_subtheme_transactions = device_subtheme_df.str.split(',').to_list()

results = apriori(device_subtheme_transactions, min_support=0.012, min_confidence=0.8, min_lift=1)
print_apyori_output(results)
# Out:
# Rules involving itemset ['Business', 'Interview']
# ['Business'] => ['Interview'] (support=0.02, confidence=0.90, lift=4.20)
#
# Rules involving itemset ['Business', 'News']
# ['Business'] => ['News'] (support=0.02, confidence=0.88, lift=4.85)
#
# Rules involving itemset ['Business', 'Politics']
# ['Business'] => ['Politics'] (support=0.02, confidence=0.87, lift=6.24)
#
# Rules involving itemset ['Business', 'Reportage']
# ['Business'] => ['Reportage'] (support=0.02, confidence=0.85, lift=11.06)
#
# Rules involving itemset ['News', 'Current Events']
# ['Current Events'] => ['News'] (support=0.05, confidence=0.85, lift=4.68)
#
# Rules involving itemset ['Drama', 'Soap']
# ['Soap'] => ['Drama'] (support=0.04, confidence=0.91, lift=5.66)
#
# Rules involving itemset ['Entertainment', 'Show']
# ['Show'] => ['Entertainment'] (support=0.02, confidence=0.87, lift=7.81)
#
# Rules involving itemset ['News', 'Politics']
# ['Politics'] => ['News'] (support=0.12, confidence=0.85, lift=4.68)
#
# Rules involving itemset ['Business', 'News', 'Interview']
# ['Business'] => ['News', 'Interview'] (support=0.02, confidence=0.86, lift=7.12)
# ['Business', 'Interview'] => ['News'] (support=0.02, confidence=0.96, lift=5.29)
# ['Business', 'News'] => ['Interview'] (support=0.02, confidence=0.98, lift=4.58)
#
# Rules involving itemset ['Business', 'Politics', 'Interview']
# ['Business'] => ['Politics', 'Interview'] (support=0.02, confidence=0.87, lift=8.23)
# ['Business', 'Interview'] => ['Politics'] (support=0.02, confidence=0.97, lift=6.94)
# ['Business', 'Politics'] => ['Interview'] (support=0.02, confidence=1.00, lift=4.67)
#
# Rules involving itemset ['Business', 'Interview', 'Reportage']
# ['Business'] => ['Interview', 'Reportage'] (support=0.02, confidence=0.85, lift=14.40)
# ['Business', 'Interview'] => ['Reportage'] (support=0.02, confidence=0.94, lift=12.26)
# ['Business', 'Reportage'] => ['Interview'] (support=0.02, confidence=1.00, lift=4.66)
#
# Rules involving itemset ['Business', 'Interview', 'STB IPTV']
# ['Business', 'STB IPTV'] => ['Interview'] (support=0.01, confidence=0.92, lift=4.29)
#
# Rules involving itemset ['Business', 'News', 'Politics']
# ['Business'] => ['News', 'Politics'] (support=0.02, confidence=0.85, lift=7.14)
# ['Business', 'News'] => ['Politics'] (support=0.02, confidence=0.96, lift=6.89)
# ['Business', 'Politics'] => ['News'] (support=0.02, confidence=0.97, lift=5.35)
#
# Rules involving itemset ['Business', 'News', 'Reportage']
# ['Business'] => ['News', 'Reportage'] (support=0.02, confidence=0.85, lift=16.63)
# ['Business', 'News'] => ['Reportage'] (support=0.02, confidence=0.96, lift=12.55)
# ['Business', 'Reportage'] => ['News'] (support=0.02, confidence=1.00, lift=5.50)
#
# Rules involving itemset ['Business', 'News', 'STB IPTV']
# ['Business', 'STB IPTV'] => ['News'] (support=0.01, confidence=0.91, lift=5.00)
#
# Rules involving itemset ['Business', 'Politics', 'Reportage']
# ['Business'] => ['Politics', 'Reportage'] (support=0.02, confidence=0.84, lift=33.45)
# ['Business', 'Politics'] => ['Reportage'] (support=0.02, confidence=0.96, lift=12.58)
# ['Business', 'Reportage'] => ['Politics'] (support=0.02, confidence=0.99, lift=7.10)
# ['Politics', 'Reportage'] => ['Business'] (support=0.02, confidence=0.88, lift=33.45)
#
# Rules involving itemset ['Business', 'Politics', 'STB IPTV']
# ['Business', 'STB IPTV'] => ['Politics'] (support=0.01, confidence=0.90, lift=6.45)
#
# Rules involving itemset ['STB IPTV', 'Business', 'Reportage']
# ['Business', 'STB IPTV'] => ['Reportage'] (support=0.01, confidence=0.88, lift=11.43)
#
# Rules involving itemset ['Interview', 'Current Events', 'Reportage']
# ['Current Events', 'Reportage'] => ['Interview'] (support=0.01, confidence=0.98, lift=4.55)
#
# Rules involving itemset ['News', 'Current Events', 'Politics']
# ['Politics', 'Current Events'] => ['News'] (support=0.03, confidence=0.98, lift=5.39)
#
# Rules involving itemset ['STB IPTV', 'News', 'Current Events']
# ['STB IPTV', 'Current Events'] => ['News'] (support=0.02, confidence=0.85, lift=4.70)
#
# Rules involving itemset ['TV', 'News', 'Current Events']
# ['TV', 'Current Events'] => ['News'] (support=0.02, confidence=0.85, lift=4.69)
#
# Rules involving itemset ['Drama', 'STB IPTV', 'Soap']
# ['Soap', 'STB IPTV'] => ['Drama'] (support=0.02, confidence=0.91, lift=5.65)
#
# Rules involving itemset ['Drama', 'TV', 'Soap']
# ['Soap', 'TV'] => ['Drama'] (support=0.02, confidence=0.91, lift=5.61)
#
# Rules involving itemset ['News', 'Interview', 'Politics']
# ['Politics', 'Interview'] => ['News'] (support=0.09, confidence=0.88, lift=4.87)
#
# Rules involving itemset ['Politics', 'Interview', 'Reportage']
# ['Politics', 'Reportage'] => ['Interview'] (support=0.03, confidence=1.00, lift=4.67)
#
# Rules involving itemset ['STB IPTV', 'Interview', 'Reportage']
# ['STB IPTV', 'Reportage'] => ['Interview'] (support=0.03, confidence=0.83, lift=3.86)
#
# Rules involving itemset ['Sports', 'Interview', 'Reportage']
# ['Sports', 'Reportage'] => ['Interview'] (support=0.01, confidence=0.97, lift=4.54)
#
# Rules involving itemset ['News', 'Politics', 'Reportage']
# ['Politics', 'Reportage'] => ['News'] (support=0.02, confidence=0.92, lift=5.07)
#
# Rules involving itemset ['STB IPTV', 'News', 'Politics']
# ['STB IPTV', 'Politics'] => ['News'] (support=0.06, confidence=0.86, lift=4.72)
#
# Rules involving itemset ['TV', 'News', 'Politics']
# ['Politics', 'TV'] => ['News'] (support=0.05, confidence=0.84, lift=4.64)
#
# Rules involving itemset ['Business', 'News', 'Interview', 'Politics']
# ['Business'] => ['News', 'Interview', 'Politics'] (support=0.02, confidence=0.85, lift=9.03)
# ['Business', 'Interview'] => ['News', 'Politics'] (support=0.02, confidence=0.94, lift=7.94)
# ['Business', 'News'] => ['Politics', 'Interview'] (support=0.02, confidence=0.96, lift=9.08)
# ['Business', 'Politics'] => ['News', 'Interview'] (support=0.02, confidence=0.97, lift=8.00)
# ['Business', 'News', 'Interview'] => ['Politics'] (support=0.02, confidence=0.98, lift=7.02)
# ['Business', 'Politics', 'Interview'] => ['News'] (support=0.02, confidence=0.97, lift=5.35)
# ['Business', 'News', 'Politics'] => ['Interview'] (support=0.02, confidence=1.00, lift=4.67)
#
# Rules involving itemset ['Business', 'News', 'Interview', 'Reportage']
# ['Business'] => ['News', 'Interview', 'Reportage'] (support=0.02, confidence=0.84, lift=24.80)
# ['Business', 'Interview'] => ['News', 'Reportage'] (support=0.02, confidence=0.94, lift=18.44)
# ['Business', 'News'] => ['Interview', 'Reportage'] (support=0.02, confidence=0.96, lift=16.34)
# ['Business', 'Reportage'] => ['News', 'Interview'] (support=0.02, confidence=1.00, lift=8.21)
# ['Business', 'News', 'Interview'] => ['Reportage'] (support=0.02, confidence=0.98, lift=12.76)
# ['Business', 'Interview', 'Reportage'] => ['News'] (support=0.02, confidence=1.00, lift=5.50)
# ['Business', 'News', 'Reportage'] => ['Interview'] (support=0.02, confidence=1.00, lift=4.66)
#
# Rules involving itemset ['Business', 'News', 'Interview', 'STB IPTV']
# ['Business', 'STB IPTV'] => ['News', 'Interview'] (support=0.01, confidence=0.89, lift=7.34)
# ['Business', 'Interview', 'STB IPTV'] => ['News'] (support=0.01, confidence=0.97, lift=5.34)
# ['Business', 'News', 'STB IPTV'] => ['Interview'] (support=0.01, confidence=0.98, lift=4.58)
#
# Rules involving itemset ['Business', 'Politics', 'Interview', 'Reportage']
# ['Business'] => ['Politics', 'Interview', 'Reportage'] (support=0.02, confidence=0.84, lift=33.45)
# ['Business', 'Interview'] => ['Politics', 'Reportage'] (support=0.02, confidence=0.94, lift=37.18)
# ['Business', 'Politics'] => ['Interview', 'Reportage'] (support=0.02, confidence=0.96, lift=16.42)
# ['Business', 'Reportage'] => ['Politics', 'Interview'] (support=0.02, confidence=0.99, lift=9.35)
# ['Politics', 'Reportage'] => ['Business', 'Interview'] (support=0.02, confidence=0.88, lift=37.18)
# ['Business', 'Politics', 'Interview'] => ['Reportage'] (support=0.02, confidence=0.96, lift=12.58)
# ['Business', 'Interview', 'Reportage'] => ['Politics'] (support=0.02, confidence=1.00, lift=7.12)
# ['Business', 'Politics', 'Reportage'] => ['Interview'] (support=0.02, confidence=1.00, lift=4.67)
# ['Politics', 'Interview', 'Reportage'] => ['Business'] (support=0.02, confidence=0.88, lift=33.45)
#
# Rules involving itemset ['Business', 'Politics', 'Interview', 'STB IPTV']
# ['Business', 'STB IPTV'] => ['Politics', 'Interview'] (support=0.01, confidence=0.90, lift=8.50)
# ['Business', 'Interview', 'STB IPTV'] => ['Politics'] (support=0.01, confidence=0.98, lift=7.01)
# ['Business', 'Politics', 'STB IPTV'] => ['Interview'] (support=0.01, confidence=1.00, lift=4.67)
#
# Rules involving itemset ['STB IPTV', 'Business', 'Interview', 'Reportage']
# ['Business', 'STB IPTV'] => ['Interview', 'Reportage'] (support=0.01, confidence=0.88, lift=14.92)
# ['Business', 'Interview', 'STB IPTV'] => ['Reportage'] (support=0.01, confidence=0.95, lift=12.44)
# ['STB IPTV', 'Business', 'Reportage'] => ['Interview'] (support=0.01, confidence=1.00, lift=4.67)
#
# Rules involving itemset ['Business', 'News', 'Politics', 'Reportage']
# ['Business'] => ['News', 'Politics', 'Reportage'] (support=0.02, confidence=0.84, lift=36.30)
# ['Business', 'News'] => ['Politics', 'Reportage'] (support=0.02, confidence=0.96, lift=37.96)
# ['Business', 'Politics'] => ['News', 'Reportage'] (support=0.02, confidence=0.96, lift=18.91)
# ['Business', 'Reportage'] => ['News', 'Politics'] (support=0.02, confidence=0.99, lift=8.36)
# ['Politics', 'Reportage'] => ['Business', 'News'] (support=0.02, confidence=0.88, lift=37.96)
# ['Business', 'News', 'Politics'] => ['Reportage'] (support=0.02, confidence=0.99, lift=12.94)
# ['Business', 'News', 'Reportage'] => ['Politics'] (support=0.02, confidence=0.99, lift=7.10)
# ['Business', 'Politics', 'Reportage'] => ['News'] (support=0.02, confidence=1.00, lift=5.50)
# ['News', 'Politics', 'Reportage'] => ['Business'] (support=0.02, confidence=0.96, lift=36.30)
# Rules involving itemset ['Business', 'News', 'Politics', 'STB IPTV']
# ['Business', 'STB IPTV'] => ['News', 'Politics'] (support=0.01, confidence=0.88, lift=7.41)
# ['Business', 'News', 'STB IPTV'] => ['Politics'] (support=0.01, confidence=0.97, lift=6.93)
# ['Business', 'Politics', 'STB IPTV'] => ['News'] (support=0.01, confidence=0.98, lift=5.38)
#
# Rules involving itemset ['STB IPTV', 'Business', 'News', 'Reportage']
# ['Business', 'STB IPTV'] => ['News', 'Reportage'] (support=0.01, confidence=0.87, lift=17.17)
# ['Business', 'News', 'STB IPTV'] => ['Reportage'] (support=0.01, confidence=0.96, lift=12.57)
# ['STB IPTV', 'Business', 'Reportage'] => ['News'] (support=0.01, confidence=1.00, lift=5.50)
#
# Rules involving itemset ['STB IPTV', 'Business', 'Politics', 'Reportage']
# ['Business', 'STB IPTV'] => ['Politics', 'Reportage'] (support=0.01, confidence=0.88, lift=34.76)
# ['Business', 'Politics', 'STB IPTV'] => ['Reportage'] (support=0.01, confidence=0.97, lift=12.66)
# ['STB IPTV', 'Business', 'Reportage'] => ['Politics'] (support=0.01, confidence=1.00, lift=7.14)
# ['STB IPTV', 'Politics', 'Reportage'] => ['Business'] (support=0.01, confidence=0.91, lift=34.47)
#
# Rules involving itemset ['STB IPTV', 'News', 'Current Events', 'Politics']
# ['STB IPTV', 'Politics', 'Current Events'] => ['News'] (support=0.01, confidence=0.97, lift=5.37)
#
# Rules involving itemset ['News', 'Interview', 'Politics', 'Reportage']
# ['Politics', 'Reportage'] => ['News', 'Interview'] (support=0.02, confidence=0.92, lift=7.59)
# ['Politics', 'Interview', 'Reportage'] => ['News'] (support=0.02, confidence=0.92, lift=5.07)
# ['News', 'Politics', 'Reportage'] => ['Interview'] (support=0.02, confidence=1.00, lift=4.67)
#
# Rules involving itemset ['STB IPTV', 'News', 'Interview', 'Politics']
# ['STB IPTV', 'Politics', 'Interview'] => ['News'] (support=0.04, confidence=0.88, lift=4.87)
#
# Rules involving itemset ['TV', 'News', 'Interview', 'Politics']
# ['TV', 'Politics', 'Interview'] => ['News'] (support=0.04, confidence=0.88, lift=4.86)
#
# Rules involving itemset ['STB IPTV', 'Politics', 'Interview', 'Reportage']
# ['STB IPTV', 'Politics', 'Reportage'] => ['Interview'] (support=0.01, confidence=1.00, lift=4.67)
#
# Rules involving itemset ['STB IPTV', 'News', 'Politics', 'Reportage']
# ['STB IPTV', 'Politics', 'Reportage'] => ['News'] (support=0.01, confidence=0.93, lift=5.15)
#
# Rules involving itemset ['Reportage', 'News', 'Politics', 'Business', 'Interview']
# ['Business'] => ['Interview', 'News', 'Politics', 'Reportage'] (support=0.02, confidence=0.84, lift=36.30)
# ['Business', 'Interview'] => ['News', 'Politics', 'Reportage'] (support=0.02, confidence=0.94, lift=40.35)
# ['Business', 'News'] => ['Politics', 'Interview', 'Reportage'] (support=0.02, confidence=0.96, lift=37.96)
# ['Business', 'Politics'] => ['News', 'Interview', 'Reportage'] (support=0.02, confidence=0.96, lift=28.28)
# ['Business', 'Reportage'] => ['Interview', 'News', 'Politics'] (support=0.02, confidence=0.99, lift=10.57)
# ['Politics', 'Reportage'] => ['Business', 'News', 'Interview'] (support=0.02, confidence=0.88, lift=38.69)
# ['Business', 'News', 'Interview'] => ['Politics', 'Reportage'] (support=0.02, confidence=0.97, lift=38.69)
# ['Business', 'Politics', 'Interview'] => ['News', 'Reportage'] (support=0.02, confidence=0.96, lift=18.91)
# ['Business', 'Interview', 'Reportage'] => ['News', 'Politics'] (support=0.02, confidence=1.00, lift=8.38)
# ['Business', 'News', 'Politics'] => ['Interview', 'Reportage'] (support=0.02, confidence=0.99, lift=16.89)
# ['Business', 'News', 'Reportage'] => ['Politics', 'Interview'] (support=0.02, confidence=0.99, lift=9.35)
# ['Business', 'Politics', 'Reportage'] => ['News', 'Interview'] (support=0.02, confidence=1.00, lift=8.23)
# ['Politics', 'Interview', 'Reportage'] => ['Business', 'News'] (support=0.02, confidence=0.88, lift=37.96)
# ['News', 'Politics', 'Reportage'] => ['Business', 'Interview'] (support=0.02, confidence=0.96, lift=40.35)
# ['Business', 'News', 'Interview', 'Politics'] => ['Reportage'] (support=0.02, confidence=0.99, lift=12.94)
# ['Business', 'News', 'Interview', 'Reportage'] => ['Politics'] (support=0.02, confidence=1.00, lift=7.12)
# ['Business', 'Politics', 'Interview', 'Reportage'] => ['News'] (support=0.02, confidence=1.00, lift=5.50)
# ['Business', 'News', 'Politics', 'Reportage'] => ['Interview'] (support=0.02, confidence=1.00, lift=4.67)
# ['News', 'Interview', 'Politics', 'Reportage'] => ['Business'] (support=0.02, confidence=0.96, lift=36.30)
#
# Rules involving itemset ['STB IPTV', 'News', 'Politics', 'Business', 'Interview']
# ['Business', 'STB IPTV'] => ['Interview', 'News', 'Politics'] (support=0.01, confidence=0.88, lift=9.37)
# ['Business', 'Interview', 'STB IPTV'] => ['News', 'Politics'] (support=0.01, confidence=0.96, lift=8.06)
# ['Business', 'News', 'STB IPTV'] => ['Politics', 'Interview'] (support=0.01, confidence=0.97, lift=9.13)
# ['Business', 'Politics', 'STB IPTV'] => ['News', 'Interview'] (support=0.01, confidence=0.98, lift=8.04)
# ['Business', 'News', 'Interview', 'STB IPTV'] => ['Politics'] (support=0.01, confidence=0.99, lift=7.07)
# ['Business', 'Politics', 'Interview', 'STB IPTV'] => ['News'] (support=0.01, confidence=0.98, lift=5.38)
# ['Business', 'News', 'Politics', 'STB IPTV'] => ['Interview'] (support=0.01, confidence=1.00, lift=4.67)
#
# Rules involving itemset ['Reportage', 'STB IPTV', 'News', 'Business', 'Interview']
# ['Business', 'STB IPTV'] => ['News', 'Interview', 'Reportage'] (support=0.01, confidence=0.87, lift=25.69)
# ['Business', 'Interview', 'STB IPTV'] => ['News', 'Reportage'] (support=0.01, confidence=0.95, lift=18.69)
# ['Business', 'News', 'STB IPTV'] => ['Interview', 'Reportage'] (support=0.01, confidence=0.96, lift=16.41)
# ['STB IPTV', 'Business', 'Reportage'] => ['News', 'Interview'] (support=0.01, confidence=1.00, lift=8.23)
# ['Business', 'News', 'Interview', 'STB IPTV'] => ['Reportage'] (support=0.01, confidence=0.98, lift=12.82)
# ['STB IPTV', 'Business', 'Interview', 'Reportage'] => ['News'] (support=0.01, confidence=1.00, lift=5.50)
# ['STB IPTV', 'Business', 'News', 'Reportage'] => ['Interview'] (support=0.01, confidence=1.00, lift=4.67)
#
# Rules involving itemset ['Reportage', 'STB IPTV', 'Politics', 'Business', 'Interview']
# ['Business', 'STB IPTV'] => ['Politics', 'Interview', 'Reportage'] (support=0.01, confidence=0.88, lift=34.76)
# ['Business', 'Interview', 'STB IPTV'] => ['Politics', 'Reportage'] (support=0.01, confidence=0.95, lift=37.82)
# ['Business', 'Politics', 'STB IPTV'] => ['Interview', 'Reportage'] (support=0.01, confidence=0.97, lift=16.52)
# ['STB IPTV', 'Business', 'Reportage'] => ['Politics', 'Interview'] (support=0.01, confidence=1.00, lift=9.41)
# ['STB IPTV', 'Politics', 'Reportage'] => ['Business', 'Interview'] (support=0.01, confidence=0.91, lift=38.33)
# ['Business', 'Politics', 'Interview', 'STB IPTV'] => ['Reportage'] (support=0.01, confidence=0.97, lift=12.66)
# ['STB IPTV', 'Business', 'Interview', 'Reportage'] => ['Politics'] (support=0.01, confidence=1.00, lift=7.14)
# ['STB IPTV', 'Business', 'Politics', 'Reportage'] => ['Interview'] (support=0.01, confidence=1.00, lift=4.67)
# ['STB IPTV', 'Politics', 'Interview', 'Reportage'] => ['Business'] (support=0.01, confidence=0.91, lift=34.47)
#
# Rules involving itemset ['Reportage', 'STB IPTV', 'News', 'Politics', 'Business']
# ['Business', 'STB IPTV'] => ['News', 'Politics', 'Reportage'] (support=0.01, confidence=0.87, lift=37.70)
# ['Business', 'News', 'STB IPTV'] => ['Politics', 'Reportage'] (support=0.01, confidence=0.96, lift=38.23)
# ['Business', 'Politics', 'STB IPTV'] => ['News', 'Reportage'] (support=0.01, confidence=0.97, lift=19.02)
# ['STB IPTV', 'Business', 'Reportage'] => ['News', 'Politics'] (support=0.01, confidence=1.00, lift=8.40)
# ['STB IPTV', 'Politics', 'Reportage'] => ['Business', 'News'] (support=0.01, confidence=0.91, lift=39.11)
# ['Business', 'News', 'Politics', 'STB IPTV'] => ['Reportage'] (support=0.01, confidence=0.99, lift=12.95)
# ['STB IPTV', 'Business', 'News', 'Reportage'] => ['Politics'] (support=0.01, confidence=1.00, lift=7.14)
# ['STB IPTV', 'Business', 'Politics', 'Reportage'] => ['News'] (support=0.01, confidence=1.00, lift=5.50)
# ['STB IPTV', 'News', 'Politics', 'Reportage'] => ['Business'] (support=0.01, confidence=0.97, lift=36.84)
# Rules involving itemset ['Reportage', 'STB IPTV', 'News', 'Politics', 'Interview']
# ['STB IPTV', 'Politics', 'Reportage'] => ['News', 'Interview'] (support=0.01, confidence=0.93, lift=7.70)
# ['STB IPTV', 'Politics', 'Interview', 'Reportage'] => ['News'] (support=0.01, confidence=0.93, lift=5.15)
# ['STB IPTV', 'News', 'Politics', 'Reportage'] => ['Interview'] (support=0.01, confidence=1.00, lift=4.67)
#
# Rules involving itemset ['Reportage', 'STB IPTV', 'News', 'Politics', 'Business', 'Interview']
# ['Business', 'STB IPTV'] => ['Interview', 'News', 'Politics', 'Reportage'] (support=0.01, confidence=0.87, lift=37.70)
# ['Business', 'Interview', 'STB IPTV'] => ['News', 'Politics', 'Reportage'] (support=0.01, confidence=0.95, lift=41.02)
# ['Business', 'News', 'STB IPTV'] => ['Politics', 'Interview', 'Reportage'] (support=0.01, confidence=0.96, lift=38.23)
# ['Business', 'Politics', 'STB IPTV'] => ['News', 'Interview', 'Reportage'] (support=0.01, confidence=0.97, lift=28.45)
# ['STB IPTV', 'Business', 'Reportage'] => ['Interview', 'News', 'Politics'] (support=0.01, confidence=1.00, lift=10.62)
# ['STB IPTV', 'Politics', 'Reportage'] => ['Business', 'News', 'Interview'] (support=0.01, confidence=0.91, lift=39.85)
# ['Business', 'News', 'Interview', 'STB IPTV'] => ['Politics', 'Reportage'] (support=0.01, confidence=0.98, lift=39.00)
# ['Business', 'Politics', 'Interview', 'STB IPTV'] => ['News', 'Reportage'] (support=0.01, confidence=0.97, lift=19.02)
# ['STB IPTV', 'Business', 'Interview', 'Reportage'] => ['News', 'Politics'] (support=0.01, confidence=1.00, lift=8.40)
# ['Business', 'News', 'Politics', 'STB IPTV'] => ['Interview', 'Reportage'] (support=0.01, confidence=0.99, lift=16.91)
# ['STB IPTV', 'Business', 'News', 'Reportage'] => ['Politics', 'Interview'] (support=0.01, confidence=1.00, lift=9.41)
# ['STB IPTV', 'Business', 'Politics', 'Reportage'] => ['News', 'Interview'] (support=0.01, confidence=1.00, lift=8.23)
# ['STB IPTV', 'Politics', 'Interview', 'Reportage'] => ['Business', 'News'] (support=0.01, confidence=0.91, lift=39.11)
# ['STB IPTV', 'News', 'Politics', 'Reportage'] => ['Business', 'Interview'] (support=0.01, confidence=0.97, lift=40.95)
# ['STB IPTV', 'News', 'Politics', 'Business', 'Interview'] => ['Reportage'] (support=0.01, confidence=0.99, lift=12.95)
# ['Reportage', 'STB IPTV', 'News', 'Business', 'Interview'] => ['Politics'] (support=0.01, confidence=1.00, lift=7.14)
# ['Reportage', 'STB IPTV', 'Politics', 'Business', 'Interview'] => ['News'] (support=0.01, confidence=1.00, lift=5.50)
# ['Reportage', 'STB IPTV', 'News', 'Politics', 'Business'] => ['Interview'] (support=0.01, confidence=1.00, lift=4.67)
# ['Reportage', 'STB IPTV', 'News', 'Politics', 'Interview'] => ['Business'] (support=0.01, confidence=0.97, lift=36.84)

# %% [markdown]
# ## Subtheme + Device + Hour Transaction

# %%
device__hour_subtheme_df = df['device_type_used'] + ',' + df_hour + ',' + df['program_subtheme']
device__hour_subtheme_transactions = device__hour_subtheme_df.str.split(',').to_list()

results = apriori(device__hour_subtheme_transactions, min_support=0.03, min_confidence=0.5, min_lift=1)
print_apyori_output(results)
# Out:
# Rules involving itemset ['STB IPTV', '21']
# ['21'] => ['STB IPTV'] (support=0.06, confidence=0.63, lift=1.40)
#
# Rules involving itemset ['STB IPTV', 'Animation']
# ['Animation'] => ['STB IPTV'] (support=0.03, confidence=0.53, lift=1.17)
#
# Rules involving itemset ['News', 'Current Events']
# ['Current Events'] => ['News'] (support=0.05, confidence=0.85, lift=4.68)
#
# Rules involving itemset ['Drama', 'Soap']
# ['Soap'] => ['Drama'] (support=0.04, confidence=0.91, lift=5.66)
#
# Rules involving itemset ['News', 'Interview']
# ['Interview'] => ['News'] (support=0.12, confidence=0.57, lift=3.12)
# ['News'] => ['Interview'] (support=0.12, confidence=0.67, lift=3.12)
#
# Rules involving itemset ['Politics', 'Interview']
# ['Politics'] => ['Interview'] (support=0.11, confidence=0.76, lift=3.54)
#
# Rules involving itemset ['Interview', 'Reportage']
# ['Reportage'] => ['Interview'] (support=0.06, confidence=0.77, lift=3.58)
#
# Rules involving itemset ['News', 'Politics']
# ['News'] => ['Politics'] (support=0.12, confidence=0.65, lift=4.68)
# ['Politics'] => ['News'] (support=0.12, confidence=0.85, lift=4.68)
#
# Rules involving itemset ['News', 'Reportage']
# ['Reportage'] => ['News'] (support=0.05, confidence=0.66, lift=3.66)
#
# Rules involving itemset ['Soccer', 'TV']
# ['Soccer'] => ['TV'] (support=0.03, confidence=0.53, lift=1.10)
#
# Rules involving itemset ['News', '21', 'Interview']
# ['21', 'Interview'] => ['News'] (support=0.03, confidence=0.93, lift=5.12)
# ['News', '21'] => ['Interview'] (support=0.03, confidence=0.78, lift=3.63)
#
# Rules involving itemset ['21', 'Interview', 'Politics']
# ['21', 'Interview'] => ['Politics'] (support=0.03, confidence=0.93, lift=6.63)
# ['21', 'Politics'] => ['Interview'] (support=0.03, confidence=0.78, lift=3.62)
#
# Rules involving itemset ['News', '21', 'Politics']
# ['News', '21'] => ['Politics'] (support=0.04, confidence=0.98, lift=7.03)
# ['21', 'Politics'] => ['News'] (support=0.04, confidence=0.98, lift=5.42)
#
# Rules involving itemset ['News', 'Interview', 'Politics']
# ['News'] => ['Politics', 'Interview'] (support=0.09, confidence=0.52, lift=4.87)
# ['Politics'] => ['News', 'Interview'] (support=0.09, confidence=0.67, lift=5.53)
# ['News', 'Interview'] => ['Politics'] (support=0.09, confidence=0.77, lift=5.53)
# ['Politics', 'Interview'] => ['News'] (support=0.09, confidence=0.88, lift=4.87)
# ['News', 'Politics'] => ['Interview'] (support=0.09, confidence=0.79, lift=3.69)
#
# Rules involving itemset ['News', 'Interview', 'Reportage']
# ['Interview', 'Reportage'] => ['News'] (support=0.03, confidence=0.58, lift=3.20)
# ['News', 'Reportage'] => ['Interview'] (support=0.03, confidence=0.67, lift=3.12)
#
# Rules involving itemset ['STB IPTV', 'News', 'Interview']
# ['STB IPTV', 'Interview'] => ['News'] (support=0.06, confidence=0.62, lift=3.42)
# ['STB IPTV', 'News'] => ['Interview'] (support=0.06, confidence=0.69, lift=3.22)
#
# Rules involving itemset ['TV', 'News', 'Interview']
# ['TV', 'Interview'] => ['News'] (support=0.06, confidence=0.54, lift=2.96)
# ['News', 'TV'] => ['Interview'] (support=0.06, confidence=0.65, lift=3.04)
#
# Rules involving itemset ['STB IPTV', 'Politics', 'Interview']
# ['STB IPTV', 'Interview'] => ['Politics'] (support=0.05, confidence=0.54, lift=3.89)
# ['STB IPTV', 'Politics'] => ['Interview'] (support=0.05, confidence=0.76, lift=3.55)
#
# Rules involving itemset ['TV', 'Politics', 'Interview']
# ['Politics', 'TV'] => ['Interview'] (support=0.05, confidence=0.76, lift=3.54)
#
# Rules involving itemset ['STB IPTV', 'News', 'Politics']
# ['STB IPTV', 'News'] => ['Politics'] (support=0.06, confidence=0.68, lift=4.87)
# ['STB IPTV', 'Politics'] => ['News'] (support=0.06, confidence=0.86, lift=4.72)
#
# Rules involving itemset ['TV', 'News', 'Politics']
# ['News', 'TV'] => ['Politics'] (support=0.05, confidence=0.63, lift=4.53)
# ['Politics', 'TV'] => ['News'] (support=0.05, confidence=0.84, lift=4.64)
#
# Rules involving itemset ['News', '21', 'Interview', 'Politics']
# ['21', 'Interview'] => ['News', 'Politics'] (support=0.03, confidence=0.92, lift=7.78)
# ['News', '21'] => ['Politics', 'Interview'] (support=0.03, confidence=0.77, lift=7.28)
# ['21', 'Politics'] => ['News', 'Interview'] (support=0.03, confidence=0.77, lift=6.37)
# ['News', '21', 'Interview'] => ['Politics'] (support=0.03, confidence=1.00, lift=7.11)
# ['21', 'Interview', 'Politics'] => ['News'] (support=0.03, confidence=1.00, lift=5.49)
# ['News', '21', 'Politics'] => ['Interview'] (support=0.03, confidence=0.79, lift=3.67)
#
# Rules involving itemset ['STB IPTV', 'News', 'Interview', 'Politics']
# ['STB IPTV', 'News'] => ['Politics', 'Interview'] (support=0.04, confidence=0.53, lift=5.03)
# ['STB IPTV', 'Politics'] => ['News', 'Interview'] (support=0.04, confidence=0.67, lift=5.54)
# ['STB IPTV', 'News', 'Interview'] => ['Politics'] (support=0.04, confidence=0.78, lift=5.54)
# ['STB IPTV', 'Politics', 'Interview'] => ['News'] (support=0.04, confidence=0.88, lift=4.87)
# ['STB IPTV', 'News', 'Politics'] => ['Interview'] (support=0.04, confidence=0.79, lift=3.67)
#
# Rules involving itemset ['TV', 'News', 'Interview', 'Politics']
# ['News', 'TV'] => ['Politics', 'Interview'] (support=0.04, confidence=0.50, lift=4.74)
# ['Politics', 'TV'] => ['News', 'Interview'] (support=0.04, confidence=0.67, lift=5.51)
# ['TV', 'News', 'Interview'] => ['Politics'] (support=0.04, confidence=0.77, lift=5.52)
# ['TV', 'Politics', 'Interview'] => ['News'] (support=0.04, confidence=0.88, lift=4.86)
# ['TV', 'News', 'Politics'] => ['Interview'] (support=0.04, confidence=0.79, lift=3.71)
